# %%
#import the necessary library
import pandas as pd

# %%
#Load the CSV File
credit_card = pd.read_csv('creditcard.csv')
credit_card
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %% [markdown]
# # EDA

# %%
#Checking the dimensions of the Datset (number of rows and columns)
rows, columns = credit_card.shape
print(f"Number of Rows: {rows}")
print(f"Number of Columns: {columns}")
# Out:
# Number of Rows: 284807
# Number of Columns: 31

# %%
#Display the first 5 rows of the Dataset
credit_card.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#Display the last 5 rows of the Dataset
credit_card.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
#Data Quality Check
credit_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#Checking for missing values
credit_card.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
print("Non-missing values: " + str(credit_card.isnull().shape[0]))
print("Missing values: " + str(credit_card.shape[0] - credit_card.isnull().shape[0]))
# Out:
# Non-missing values: 284807
# Missing values: 0

# %%
# cheking duplicates in dataset
credit_card.duplicated().any()
# Out:
# True

# %%
# checking dimentions of dataset
credit_card.shape
# Out:
# (284807, 31)

# %%
# Remove duplication
data= credit_card.drop_duplicates()

# %%
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
data.shape
# Out:
# (283726, 31)

# %%
print(f"Dublicate Transaction:", len(credit_card) - len(data))
# Out:
# Dublicate Transaction: 1081

# %%
#Display columns name
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %% [markdown]
# # Feature Engineering

# %%
fraud = data[data['Class']==1]
normal = data[data['Class']==0]

# %%
normal, fraud = data['Class'].value_counts()
print(f"Normal Transactions (0): {normal}")
print(f"Fraud Transactions(1): {fraud}")
# Out:
# Normal Transactions (0): 283253
# Fraud Transactions(1): 473

# %%
#Let's find out the percentage of fraud and non fraud transacation

print('Normal Transactions found:', round(data['Class'].value_counts()[0]/len(data) * 100,2),'%')
print('Fraud Transactions found:', round(data['Class'].value_counts()[1]/len(data) * 100,2),'%')
# Out:
# Normal Transactions found: 99.83 %
# Fraud Transactions found: 0.17 %

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x = 'Class', data=data)
plt.title('Class Distribution \n (Normal Transactions: 0 || Fraud Transactions: 1)')
plt.show()

# %% [markdown]
# We can clearly see our dataset is highly skewed and if we use our any of classification models it is going to give errors in results. Also we can't use traditional accuracy score to evaluate model performance. This data imbalance can be dealt using resampling methods; upsampling and downsampling.
#
# In upsampling or oversampling we increase the minority class to match with the majority class.
# In downsampling or undersampling some data has been deleted from the majority class randomly to match it with the minority class data.
# Here we will be using SMOTE (Synthetic Minority Oversampling Technique) to resample this data.

# %%
data.hist(bins=30,figsize=(30,30))
plt.show()

# %%
plt.figure(figsize=(30, 25))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %% [markdown]
# # Feature Selection

# %%
X = data.drop('Class', axis=1)
Y = data['Class']

# %%
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
Y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 283726, dtype: int64

# %% [markdown]
# # Handling Imbalanced Data:

# %% [markdown]
# Handling imbalanced data is a crucial aspect of machine learning, as many real-world datasets often have significant class imbalances. Resampling techniques are commonly used to address this issue.It consists of removing       samples from the majority class (under-sampling) or adding more examples from the minority class (over-sampling).

# %% [markdown]
# I handle imbalanced data using Synthetic Minority Oversampling Technique (SMOTE)
#               SMOTE (Synthetic Minority Oversampling Technique) works by randomly picking a point from the minority     class and computing the k-nearest neighbors for this point. The synthetic points are added between the chosen point and its neighbors.
# SMOTE algorithm works in 4 simple steps:
#
# Choose a minority class as the input vector.
# Find its k nearest neighbors (k_neighbors is specified as an argument in the SMOTE() function).
# Choose one of these neighbors and place a synthetic point anywhere on the line joining the point under consideration and its chosen neighbor.
# Repeat the steps until the data is balanced.

# %%
X.shape
# Out:
# (283726, 30)

# %%
Y.shape
# Out:
# (283726,)

# %%
 from imblearn.over_sampling import SMOTE
    # You can specify a random state for reproducibility
smote = SMOTE(random_state=42) 
x_smote, y_smote = smote.fit_resample(X, Y)

# %%
y_smote.value_counts()
# Out:
# 0    283253
# 1    283253
# Name: Class, dtype: int64

# %%
x_smote.value_counts()
# Out:
# Time           V1         V2         V3         V4         V5         V6         V7         V8         V9         V10        V11        V12        V13        V14        V15        V16        V17        V18        V19        V20        V21        V22        V23        V24        V25        V26        V27        V28        Amount
# 0.000000       -1.359807  -0.072781   2.536347   1.378155  -0.338321   0.462388   0.239599   0.098698   0.363787   0.090794  -0.551600  -0.617801  -0.991390  -0.311169   1.468177  -0.470401   0.207971   0.025791   0.403993   0.251412  -0.018307   0.277838  -0.110474   0.066928   0.128539  -0.189115   0.133558  -0.021053  149.620000    1
# ...

# %%
x_smote
# Out:
#                  Time        V1        V2         V3        V4        V5  \
# 0            0.000000 -1.359807 -0.072781   2.536347  1.378155 -0.338321
# 1            0.000000  1.191857  0.266151   0.166480  0.448154  0.060018
# 2            1.000000 -1.358354 -1.340163   1.773209  0.379780 -0.503198
# 3            1.000000 -0.966272 -0.185226   1.792993 -0.863291 -0.010309
# 4            2.000000 -1.158233  0.877737   1.548718  0.403034 -0.407193
# ...               ...       ...       ...        ...       ...       ...
# 566501   41183.445750 -7.151786  5.337862 -10.524210  6.638176 -7.107253
# 566502   14264.057012 -4.705909  8.250299 -14.559164  9.787990 -4.117161
# 566503  135064.971368  0.407366  1.352354  -4.892782  3.554728 -1.282114
# 566504  109361.849259  0.580032  2.773047  -5.790024  5.606953  0.398480
# 566505   84438.552579 -2.819178  2.410529  -5.833727  4.099991 -2.622497
#
#               V6         V7        V8        V9  ...       V20       V21  \
# ...

# %%
y_smote
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 566501    1
# 566502    1
# 566503    1
# 566504    1
# 566505    1
# Name: Class, Length: 566506, dtype: int64

# %%
from collections import Counter
print('Original dataset shape', Counter(Y))
print('Resample dataset shape', Counter(y_smote))
# Out:
# Original dataset shape Counter({0: 283253, 1: 473})
# Resample dataset shape Counter({0: 283253, 1: 283253})

# %% [markdown]
# # Split the Dataset for Test and Train

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x_smote, y_smote, test_size=0.30, random_state=42)

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fraud_data = data[data['Class'] == 0]
nonfraud_data = data[data['Class'] == 1]
plt.title("Transaction Amount - Fraud vs. Non-Fraud")
plt.xlabel("Amount ($)")
plt.ylabel("Frequency")
sns.histplot(fraud_data['Amount'],bins=50,kde=True, label="Fraud")
sns.histplot(nonfraud_data['Amount'], bins=50,kde=True,label="Non-Fraud")
plt.legend()
plt.show()

# %%
plt.title("Transaction Amount")
sns.boxplot(x="Class", y="Amount", data=data)
plt.show()

# %%
corr_imbalanced = data.corr()
sns.heatmap(corr_imbalanced, annot=False)
plt.title("Correlation Matrix for Imbalanced Data")
plt.show()

# %%
corr_balanced = x_smote.corr()
sns.heatmap(corr_balanced, annot=False)
plt.title("Correlation Matrix for Balanced Data")
plt.show()

# %%
sns.countplot(x="Class", data=data)
plt.title('Class Distribution \n (Normal Transactions : 0 || Fraud Transactions: 1)')
plt.show()

# %%
print('Normal Transactions found:', round(data['Class'].value_counts()[0]/len(data) * 100,2),'%')
print('Fraud Transactions found:', round(data['Class'].value_counts()[1]/len(data) * 100,2),'%')
# Out:
# Normal Transactions found: 99.83 %
# Fraud Transactions found: 0.17 %

# %%
sns.countplot(x=y_smote)
plt.title("Class Distribution After Resampling (SMOTE)\n (Normal Transactions: 0 || Fraud Transactions: 1)")
plt.show()

# %%
#Let's find out the percentage of fraud and non fraud transacation

print('Normal Transactions found:', round(y_smote.value_counts()[0]/len(data) * 100,2),'%')
print('Fraud Transactions found:', round(y_smote.value_counts()[1]/len(data) * 100,2),'%')
# Out:
# Normal Transactions found: 99.83 %
# Fraud Transactions found: 99.83 %

# %% [markdown]
# # Model Building

# %%
#Training the logistic Regression model on the training set
from sklearn.linear_model import LogisticRegression

logis_model = LogisticRegression()
logis_model.fit(X_train, Y_train)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
test_pred = logis_model.predict(X_test)
train_pred = logis_model.predict(X_train)

# %%
from sklearn.metrics import confusion_matrix, precision_recall_curve, classification_report, precision_score, recall_score, accuracy_score

# %% [markdown]
#  Calculate performance metrics for the Logistic Regression model

# %%
# Calculate performance metrics for the Logistic Regression model
confusion_matrix_logistic = confusion_matrix(Y_test, test_pred)
classification_report_logistic = classification_report(Y_test, test_pred, output_dict=True)

confusion_matrix_df = pd.DataFrame(confusion_matrix_logistic, 
                                   columns=["Predicted Negative (0)", "Predicted Positive (1)"],
                                   index=["Actual Negative (0)", "Actual Positive (1)"])

classification_report_df = pd.DataFrame(classification_report_logistic)

print("Logistic Regression Model - Confusion Matrix:")
print(confusion_matrix_df)

print("\nLogistic Regression Model - Classification Report:")
print(classification_report_df)
print("Training Data Accuracy: ",accuracy_score(train_pred, Y_train))
print("Test Data Accuracy: ", accuracy_score(test_pred, Y_test))
# Out:
# Logistic Regression Model - Confusion Matrix:
#                      Predicted Negative (0)  Predicted Positive (1)
# Actual Negative (0)                   83389                    1491
# Actual Positive (1)                    3226                   81846
#
# Logistic Regression Model - Classification Report:
#                       0             1  accuracy      macro avg   weighted avg
# precision      0.962755      0.982109  0.972245       0.972432       0.972443
# recall         0.982434      0.962079  0.972245       0.972257       0.972245
# f1-score       0.972495      0.971991  0.972245       0.972243       0.972243
# support    84880.000000  85072.000000  0.972245  169952.000000  169952.000000
# Training Data Accuracy:  0.9716684234681784
# Test Data Accuracy:  0.9722451045000942

# %%
sns.heatmap(confusion_matrix_df, annot=True,fmt="d")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Training the Random Forest model on training set
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier()
RF.fit(X_train, Y_train)

# Predicting the results
test_pred1 = RF.predict(X_test)
train_pred1 = RF.predict(X_train)

# %%
# Calculate performance metrics for the Logistic Regression model
confusion_matrix_Random = confusion_matrix(Y_test, test_pred1)
classification_report_Random = classification_report(Y_test, test_pred1, output_dict=True)

confusion_matrix_df1 = pd.DataFrame(confusion_matrix_Random, 
                                   columns=["Predicted Negative (0)", "Predicted Positive (1)"],
                                   index=["Actual Negative (0)", "Actual Positive (1)"])

classification_report_df1 = pd.DataFrame(classification_report_Random)

print("Random Forest Model - Confusion Matrix:")
print(confusion_matrix_df1)

print("\nRandom Forest Model- Classification Report:")
print(classification_report_df1)
print("Training Data Accuracy: ",accuracy_score(train_pred1, Y_train))
print("Test Data Accuracy: ", accuracy_score(test_pred1, Y_test))

# %%
sns.heatmap(confusion_matrix_df, annot=True,fmt="d")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
final_data = pd.DataFrame({'Models':['logis_model','RF'],
              "ACC":[accuracy_score(test_pred, Y_test)*100,
                     accuracy_score(test_pred1, Y_test)*100
                    ]})

# %%
final_data
